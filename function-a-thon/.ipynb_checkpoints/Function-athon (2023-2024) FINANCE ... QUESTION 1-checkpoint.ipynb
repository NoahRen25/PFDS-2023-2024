# %% [markdown]
# # <center><b>PFDS</b></center>
# # <center><b>2023-2024</b></center>
# # <center><b>Function-athon</b></center>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### NAMES OF PEOPLE IN YOUR GROUP:<br>
#
# 1.
#
# 2.
#
# 3.
#
# 4.
#
# 5.
#
# </div>

# %%
# set up notebook to display multiple output in one cell

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

print('The notebook is set up to display multiple output in one cell.')
# Out:
# The notebook is set up to display multiple output in one cell.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # <center>FINANCE</center>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #1:</b><br>
#
# ![image-2.png](attachment:image-2.png)
#
# <hr style="border:1px solid gray">
#
# Write a function called ord_annuity_fv that can be used to calculate the future value of an ordinary annuity. Your function should have parameters for the periodic payment, the annual interest rate, the number of compounding periods per year, and the time in years.<br>
#
# <hr style="border:1px solid gray">
#
# **Use your function to find an answer to the following question:**<br>
#
# In two years, the Smith's want to purchase a home in the \\$650000 - \\$700000 price range. To acquire financing, they anticipate that will have to be able to make a 20\% down payment. To save for the down payment, they decide to start an ordinary annuity. To fund the annuity, for the next two years, they plan to make a payment of \\$5500 at the end of each month. They also expect that over the next two years they will be able to earn an annual interest rate of 6.25\%.<br>
#
# Will the Smith's have enough money in their ordinary annuity at the end of two years to guarantee that they will be able to make a 20% down payment for a home in their desired price range?  Provide aesthetically formatted, detailed output to support you answer.
# </div>
