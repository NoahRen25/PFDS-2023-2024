# %% [markdown]
# # Scenario 1

# %%
status = input('Please enter your filing status (single, married filing jointly, married filing separately, head of household): ')
income = eval(input('Please enter your income: '))

if('single' in status.lower()):
    if(income <= 9950):
        tax = income * 0.1
    elif(income <= 40525):
        income -= 9950
        tax = 995 + (income * 0.12)
    elif(income <= 86375):
        income -= 40525
        tax = 4664 + (income * 0.22)
    elif(income <= 164925):
        income -= 86375
        tax = 14751 + (income * 0.24)
    elif(income <= 209425):
        income -= 164925
        tax = 33603 + (income * 0.32)
    elif(income <= 523600):
        income -= 209425
        tax = 47843 + (income * 0.35)
    else:
        income -= 523600
        tax = 157804.25 + (income * 0.37)
#Married, filing jointly
elif('filing jointly' in status.lower()):
    if(income <= 19900):
        tax = income * 0.1
    elif(income <= 81050):
        income -= 19900
        tax = 1990 + (income * 0.12)
    elif(income <= 172750):
        income -= 81050
        tax = 9328 + (income * 0.22)
    elif(income <= 329850):
        income -= 172750
        tax = 29502 + (income * 0.24)
    elif(income <= 418850):
        income -= 329850
        tax = 67206 + (income * 0.32)
    elif(income <= 628300):
        income -= 418850
        tax = 95686 + (income * 0.35)
    else:
        income -= 628300
        tax = 168993.5+ (income * 0.37)
elif('filing separately' in status.lower()):
    if(income <= 9950):
        tax = income * 0.1
    elif(income <= 40525):
        income -= 9950
        tax = 995 + (income * 0.12)
    elif(income <= 86375):
        income -= 40525
        tax = 4664 + (income * 0.22)
    elif(income <= 164925):
        income -= 86375
        tax = 14751 + (income * 0.24)
    elif(income <= 209425):
        income -= 164925
        tax = 33603 + (income * 0.32)
    elif(income <= 314150):
        income -= 209425
        tax = 47843 + (income * 0.35)
    else:
        income -= 314150
        tax = 84496.75 + (income * 0.37)
elif('head of household' in status.lower()):
    if(income <= 14200):
        tax = income * 0.1
    elif(income <= 54200):
        income -= 14200
        tax = 1420 + (income * 0.12)
    elif(income <= 86350):
        income -= 54200
        tax = 6220 + (income * 0.22)
    elif(income <= 164900):
        income -= 86350
        tax = 13293 + (income * 0.24)
    elif(income <= 209400):
        income -= 164900
        tax = 32145 + (income * 0.32)
    elif(income <= 523600):
        income -= 209400
        tax = 46385 + (income * 0.35)
    else:
        income -= 523600
        tax = 156355 + (income * 0.37)
else:
    print('Invalid status!')
print(f'Based on your filing status and income, you must pay ${tax} in taxes')
# Out:
# Please enter your filing status (single, married filing jointly, married filing separately, head of household): single
# Please enter your income: 175000
# Based on your filing status and income, you must pay $36827.0 in taxes

# %% [markdown]
# # Scenario 2

# %%
status = input('Please enter your filing status (single, married filing jointly, married filing separately, head of household): ')
income = eval(input('Please enter your income: '))
if('single' in status.lower()):
    if(income <= 9950):
        tax = income * 0.1
    elif(income <= 40525):
        income -= 9950
        tax = 995 + (income * 0.12)
    elif(income <= 86375):
        income -= 40525
        tax = 4664 + (income * 0.22)
    elif(income <= 164925):
        income -= 86375
        tax = 14751 + (income * 0.24)
    elif(income <= 209425):
        income -= 164925
        tax = 33603 + (income * 0.32)
    elif(income <= 523600):
        income -= 209425
        tax = 47843 + (income * 0.35)
    else:
        income -= 523600
        tax = 157804.25 + (income * 0.37)
#Married, filing jointly
elif('filing jointly' in status.lower()):
    if(income <= 19900):
        tax = income * 0.1
    elif(income <= 81050):
        income -= 19900
        tax = 1990 + (income * 0.12)
    elif(income <= 172750):
        income -= 81050
        tax = 9328 + (income * 0.22)
    elif(income <= 329850):
        income -= 172750
        tax = 29502 + (income * 0.24)
    elif(income <= 418850):
        income -= 329850
        tax = 67206 + (income * 0.32)
    elif(income <= 628300):
        income -= 418850
        tax = 95686 + (income * 0.35)
    else:
        income -= 628300
        tax = 168993.5+ (income * 0.37)
elif('filing separately' in status.lower()):
    if(income <= 9950):
        tax = income * 0.1
    elif(income <= 40525):
        income -= 9950
        tax = 995 + (income * 0.12)
    elif(income <= 86375):
        income -= 40525
        tax = 4664 + (income * 0.22)
    elif(income <= 164925):
        income -= 86375
        tax = 14751 + (income * 0.24)
    elif(income <= 209425):
        income -= 164925
        tax = 33603 + (income * 0.32)
    elif(income <= 314150):
        income -= 209425
        tax = 47843 + (income * 0.35)
    else:
        income -= 314150
        tax = 84496.75 + (income * 0.37)
elif('head of household' in status.lower()):
    if(income <= 14200):
        tax = income * 0.1
    elif(income <= 54200):
        income -= 14200
        tax = 1420 + (income * 0.12)
    elif(income <= 86350):
        income -= 54200
        tax = 6220 + (income * 0.22)
    elif(income <= 164900):
        income -= 86350
        tax = 13293 + (income * 0.24)
    elif(income <= 209400):
        income -= 164900
        tax = 32145 + (income * 0.32)
    elif(income <= 523600):
        income -= 209400
        tax = 46385 + (income * 0.35)
    else:
        income -= 523600
        tax = 156355 + (income * 0.37)
else:
    print('Invalid status!')
print(f'Based on your filing status and income, you must pay ${tax} in taxes')
# Out:
# Please enter your filing status (single, married filing jointly, married filing separately, head of household): married, filing jointly
# Please enter your income: 91500
# Based on your filing status and income, you must pay $11627.0 in taxes

# %% [markdown]
# # Scenario 3

# %%
status = input('Please enter your filing status (single, married filing jointly, married filing separately, head of household): ')
income = eval(input('Please enter your income: '))

if('single' in status.lower()):
    if(income <= 9950):
        tax = income * 0.1
    elif(income <= 40525):
        income -= 9950
        tax = 995 + (income * 0.12)
    elif(income <= 86375):
        income -= 40525
        tax = 4664 + (income * 0.22)
    elif(income <= 164925):
        income -= 86375
        tax = 14751 + (income * 0.24)
    elif(income <= 209425):
        income -= 164925
        tax = 33603 + (income * 0.32)
    elif(income <= 523600):
        income -= 209425
        tax = 47843 + (income * 0.35)
    else:
        income -= 523600
        tax = 157804.25 + (income * 0.37)
#Married, filing jointly
elif('filing jointly' in status.lower()):
    if(income <= 19900):
        tax = income * 0.1
    elif(income <= 81050):
        income -= 19900
        tax = 1990 + (income * 0.12)
    elif(income <= 172750):
        income -= 81050
        tax = 9328 + (income * 0.22)
    elif(income <= 329850):
        income -= 172750
        tax = 29502 + (income * 0.24)
    elif(income <= 418850):
        income -= 329850
        tax = 67206 + (income * 0.32)
    elif(income <= 628300):
        income -= 418850
        tax = 95686 + (income * 0.35)
    else:
        income -= 628300
        tax = 168993.5+ (income * 0.37)
elif('filing separately' in status.lower()):
    if(income <= 9950):
        tax = income * 0.1
    elif(income <= 40525):
        income -= 9950
        tax = 995 + (income * 0.12)
    elif(income <= 86375):
        income -= 40525
        tax = 4664 + (income * 0.22)
    elif(income <= 164925):
        income -= 86375
        tax = 14751 + (income * 0.24)
    elif(income <= 209425):
        income -= 164925
        tax = 33603 + (income * 0.32)
    elif(income <= 314150):
        income -= 209425
        tax = 47843 + (income * 0.35)
    else:
        income -= 314150
        tax = 84496.75 + (income * 0.37)
elif('head of household' in status.lower()):
    if(income <= 14200):
        tax = income * 0.1
    elif(income <= 54200):
        income -= 14200
        tax = 1420 + (income * 0.12)
    elif(income <= 86350):
        income -= 54200
        tax = 6220 + (income * 0.22)
    elif(income <= 164900):
        income -= 86350
        tax = 13293 + (income * 0.24)
    elif(income <= 209400):
        income -= 164900
        tax = 32145 + (income * 0.32)
    elif(income <= 523600):
        income -= 209400
        tax = 46385 + (income * 0.35)
    else:
        income -= 523600
        tax = 156355 + (income * 0.37)
else:
    print('Invalid status!')
print(f'Based on your filing status and income, you must pay ${tax} in taxes')
# Out:
# Please enter your filing status (single, married filing jointly, married filing separately, head of household): married filing separately
# Please enter your income: 86800
# Based on your filing status and income, you must pay $14853.0 in taxes

# %% [markdown]
# # Scenario 4

# %%
status = input('Please enter your filing status (single, married filing jointly, married filing separately, head of household): ')
income = eval(input('Please enter your income: '))

if('single' in status.lower()):
    if(income <= 9950):
        tax = income * 0.1
    elif(income <= 40525):
        income -= 9950
        tax = 995 + (income * 0.12)
    elif(income <= 86375):
        income -= 40525
        tax = 4664 + (income * 0.22)
    elif(income <= 164925):
        income -= 86375
        tax = 14751 + (income * 0.24)
    elif(income <= 209425):
        income -= 164925
        tax = 33603 + (income * 0.32)
    elif(income <= 523600):
        income -= 209425
        tax = 47843 + (income * 0.35)
    else:
        income -= 523600
        tax = 157804.25 + (income * 0.37)
#Married, filing jointly
elif('filing jointly' in status.lower()):
    if(income <= 19900):
        tax = income * 0.1
    elif(income <= 81050):
        income -= 19900
        tax = 1990 + (income * 0.12)
    elif(income <= 172750):
        income -= 81050
        tax = 9328 + (income * 0.22)
    elif(income <= 329850):
        income -= 172750
        tax = 29502 + (income * 0.24)
    elif(income <= 418850):
        income -= 329850
        tax = 67206 + (income * 0.32)
    elif(income <= 628300):
        income -= 418850
        tax = 95686 + (income * 0.35)
    else:
        income -= 628300
        tax = 168993.5+ (income * 0.37)
elif('filing separately' in status.lower()):
    if(income <= 9950):
        tax = income * 0.1
    elif(income <= 40525):
        income -= 9950
        tax = 995 + (income * 0.12)
    elif(income <= 86375):
        income -= 40525
        tax = 4664 + (income * 0.22)
    elif(income <= 164925):
        income -= 86375
        tax = 14751 + (income * 0.24)
    elif(income <= 209425):
        income -= 164925
        tax = 33603 + (income * 0.32)
    elif(income <= 314150):
        income -= 209425
        tax = 47843 + (income * 0.35)
    else:
        income -= 314150
        tax = 84496.75 + (income * 0.37)
elif('head of household' in status.lower()):
    if(income <= 14200):
        tax = income * 0.1
    elif(income <= 54200):
        income -= 14200
        tax = 1420 + (income * 0.12)
    elif(income <= 86350):
        income -= 54200
        tax = 6220 + (income * 0.22)
    elif(income <= 164900):
        income -= 86350
        tax = 13293 + (income * 0.24)
    elif(income <= 209400):
        income -= 164900
        tax = 32145 + (income * 0.32)
    elif(income <= 523600):
        income -= 209400
        tax = 46385 + (income * 0.35)
    else:
        income -= 523600
        tax = 156355 + (income * 0.37)
else:
    print('Invalid status!')
print(f'Based on your filing status and income, you must pay ${tax} in taxes')
# Out:
# Please enter your filing status (single, married filing jointly, married filing separately, head of household): head of household
# Please enter your income: 205000
# Based on your filing status and income, you must pay $44977.0 in taxes
