# %% [markdown]
# # <center><b>PFDS</b></center>
# # <center><b>Asg 6.1</b></center>
# # <center><b>The Absolute Basics</b></center>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #1:</b>
#
# <b>Short Answers:</b>
# <p>&nbsp;</p>
# a. Instructions written in source code are called ___________________________________.
# <p>&nbsp;</p>
# b. The preferred indentation method in Python is ____________________________________.
# <p>&nbsp;</p>
# c. Is it more accurate to say that variables in Python are containers or labels?<br>
# <p>&nbsp;</p>
# d. In Python, a combination of operators and operands (variables and values) that represent a single result value is
#    called a/an _______________.<br>
# <p>&nbsp;</p>
# e. True or False: (If False, explain why the statement is False.)&ensp;<i>Arithmetic operators involving integers always return an integer.</i>
# <p>&nbsp;</p>
# f. True or False: (If False, explain why the statement is False.)&ensp;<i>In traditional integer division the result gets rounded.</i>
# <p>&nbsp;</p>
# g. What Python basic data type defines a single special data object that is used to represent an empty value?
# <p>&nbsp;</p>
# h. The resuly of the input() function always outputs as a ____________.  So if you want to use that output as a number in a calculation, you must first do a ________ __________.<br>
# <p>&nbsp;</p>
# i. What do the \n characters do?
# <p>&nbsp;</p>
# j. What do the \t characters do?
# <p>&nbsp;</p>
# </div>

# %% [markdown]
# ### Answers for Question #1

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #2:</b>
#
# Found below is the first half this week's AP Top 25 college football teams.
# <p>&nbsp;</p>
# <b>Instructions:</b><br>
#
# Write code that uses a **multi-line statement** to display the top 12 teams in this week's rankings.
#
# ![Rankings-2.JPG](attachment:Rankings-2.JPG)
# </div>

# %% [markdown]
# ### Answer for Question #2
