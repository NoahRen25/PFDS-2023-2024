# %%
class Store:
    def __init__ (self):
        self.income = 0
        self.stock = {}
class pcStore(Store):
    def __init__ (self,income):
        #super.__init__(self)
        self.income = 0
        self.prices = {
            # Nvidia Graphics Cards
            'Nvidia GeForce GTX 1650': 150,
            'Nvidia GeForce GTX 1660': 250,
            'Nvidia GeForce GTX 1660 SUPER': 260,
            'Nvidia GeForce RTX 3060': 400,
            'Nvidia GeForce RTX 3070': 700,
            'Nvidia GeForce RTX 3080': 900,
            'Nvidia GeForce RTX 3090': 1500,

            # AMD Graphics Cards
            'AMD Radeon RX 5500 XT': 200,
            'AMD Radeon RX 5600 XT': 300,
            'AMD Radeon RX 5700 XT': 400,
            'AMD Radeon RX 6700 XT': 480,
            'AMD Radeon RX 6800': 650,
            'AMD Radeon RX 6900 XT': 1000,

            # Intel Processors
            'Intel Core i3-10100': 150,
            'Intel Core i5-10400': 200,
            'Intel Core i7-10700K': 400,
            'Intel Core i9-10900K': 550,
            'Intel Core i5-11600K': 300,
            'Intel Core i7-11700K': 450,
            'Intel Core i9-11900K': 600,
            'Intel Core i5-12600K': 350,
            'Intel Core i7-12700K': 500,

            # ASUS Motherboards
            'Asus Prime Z490-A': 200,
            'Asus ROG Strix B460-F': 150,
            'Asus TUF Gaming B560-PLUS': 120,
            'Asus ROG Strix B560-E': 180,
            'Asus Prime H470-PRO': 130,
            'Asus ROG Strix Z590-E': 250,
            'Asus Prime B450M-A': 90,
            'Asus ROG Strix X570-E': 300,
            'Asus TUF Gaming B550M-PLUS': 150,
            'Asus Prime H510M-E': 80,
            'Asus ROG Strix Z690-E': 350,
            'Asus TUF Gaming B660-PLUS': 200,
            'Asus ROG Maximus Z690-A': 400,
            'Asus ROG Strix B660-I': 180,
            'Asus Prime Z590M-PLUS': 160,
            'Asus TUF Gaming X570-PLUS': 180,
            'Asus ROG Strix Z690-I': 320,
            'Asus Prime H570M-PLUS': 120,
            'Asus ROG Strix B560-M': 140,
            'Asus ROG Strix B550-F': 180,

            # Gigabyte Motherboards
            'Gigabyte B450 AORUS PRO': 120,
            'Gigabyte B550 AORUS ELITE': 180,
            'Gigabyte Z590 AORUS PRO AX': 250,
            'Gigabyte X570 AORUS MASTER': 350,
            'Gigabyte B460M DS3H': 90,
            'Gigabyte B550M AORUS PRO-P': 120,
            'Gigabyte H510M H': 80,
            'Gigabyte B450M DS3H': 90,
            'Gigabyte Z390 AORUS PRO': 200,
            'Gigabyte Z490 AORUS XTREME': 400,
            'Gigabyte Z690 AORUS MASTER': 350,
            'Gigabyte X299 AORUS MASTER': 400,
            'Gigabyte Z370 AORUS Gaming 7': 250,
            'Gigabyte Z390 AORUS PRO WIFI': 220,
            'Gigabyte Z590 AORUS ULTRA': 300,
            'Gigabyte X570 AORUS ULTRA': 300,
            'Gigabyte B450 AORUS M': 90,
            'Gigabyte X470 AORUS GAMING 5': 150,
            'Gigabyte Z370 AORUS Gaming 5': 200,
            'Gigabyte B550M DS3H': 100,

            # ASUS Graphics Cards
            'Asus Dual GeForce GTX 1650': 150,
            'Asus ROG Strix Radeon RX 6700 XT': 550,
            'Asus TUF Gaming Radeon RX 6800 XT': 700,
            'Asus Dual GeForce RTX 2060': 300,
            'Asus ROG Strix GeForce RTX 3070': 700,
            'Asus TUF Gaming GeForce RTX 3080': 900,
            'Asus Dual GeForce GTX 1660 Ti': 270,
            'Asus ROG Strix Radeon RX 6600 XT': 400,
            'Asus TUF Gaming GeForce RTX 3090': 1300,
            'Asus ROG Strix GeForce RTX 3060': 500,
            'Asus Dual GeForce GTX 1660 SUPER': 280,
            'Asus ROG Strix Radeon RX 6800': 800,
            'Asus TUF Gaming GeForce RTX 3070': 800,
            'Asus Dual GeForce GTX 1660': 250,
            'Asus ROG Strix Radeon RX 6900 XT': 1000,
            'Asus TUF Gaming GeForce GTX 1650 SUPER': 170,
            'Asus Dual GeForce RTX 3060 Ti': 600,
            'Asus TUF Gaming GeForce RTX 3060': 550,
            'Asus Dual GeForce RTX 3070': 700,
            'Asus ROG Strix Radeon RX 6700': 500,

            # Gigabyte Graphics Cards
            'Gigabyte GeForce GTX 1650 SUPER': 170,
            'Gigabyte AORUS GeForce RTX 3080 XTREME': 1000,
            'Gigabyte Radeon RX 6900 XT GAMING OC': 1100,
            'Gigabyte GeForce GTX 1660 SUPER': 260,
            'Gigabyte AORUS GeForce RTX 3090 XTREME': 1200,
            'Gigabyte Radeon RX 6700 XT GAMING OC': 550,
            'Gigabyte GeForce RTX 3060 Ti GAMING OC': 600,
            'Gigabyte AORUS GeForce RTX 3070 XTREME': 900,
            'Gigabyte Radeon RX 6800 XT GAMING OC': 700,
            'Gigabyte GeForce GTX 1660 Ti OC': 270,
            'Gigabyte AORUS GeForce RTX 3080 MASTER': 950,
            'Gigabyte Radeon RX 6600 XT GAMING OC': 400,
            'Gigabyte GeForce RTX 3060 GAMING OC': 500,
            'Gigabyte AORUS Radeon RX 6700 XT MASTER': 580,
            'Gigabyte GeForce RTX 3070 GAMING OC': 750,
            'Gigabyte AORUS GeForce GTX 1660 Ti': 280,
            'Gigabyte AORUS GeForce RTX 3070 MASTER': 800,
            'Gigabyte Radeon RX 6800 GAMING OC': 800,
            'Gigabyte GeForce GTX 1660 OC': 250,
            'Gigabyte AORUS Radeon RX 6600 XT MASTER': 450,
            }
    def buy(self,part):
        try:
            self.income += self.prices[part]
        except:
            return "name Error please have it Case sensitive"
    def sell(self,part):
        self.income -= self.prices[part]
    
c = pcStore(0)
print(c.buy('Nvidia Geforce GTX 1650'))
print(c.income)
# Out:
# name Error please have it Case sensitive
# 0
