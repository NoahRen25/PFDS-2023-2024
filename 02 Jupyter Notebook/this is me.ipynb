# %% [markdown]
# <b> Noah Ren </b>

# %% [markdown]
# [this is me](https://docs.google.com/document/d/1p6pf2CwOQ8vVKaGYJA7cIvJpIMV7JEM70QsMwph1gE4/edit?usp=sharing)
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***
# ***

# %% [markdown]
# # i enjoy software

# %% [markdown]
# <div class="alert alert-block alert-warning">Over the past 2 summers, I've done a software internship with Code The Way, working out of the Artisan Partners office. Additionally, I enjoy coding in robotics. (messed around some on my own with python, otherwise java/reactjs)

# %% [markdown]
# ![Screenshot%202023-09-11%20223738.png](attachment:Screenshot%202023-09-11%20223738.png)

# %% [markdown]
# ## i enjoy statistics & finance

# %% [markdown]
# <div class="alert alert-block alert-success">i've been helping habitat for humanity with their sales system. i've also delved innto the world of finance through my own research (applied materials!!) </div>

# %% [markdown]
# ![Screenshot%202023-09-11%20224058.png](attachment:Screenshot%202023-09-11%20224058.png)

# %% [markdown]
# ### extra-curriculurs are good

# %% [markdown]
# <div class="alert alert-block alert-info">
# Besides robotics, I also enjoy both forensics and debate, and being in Scouts (Eagle ~ a year ago). I also enjoy playing tennis

# %% [markdown]
# ![Screenshot%202023-09-11%20224627.png](attachment:Screenshot%202023-09-11%20224627.png)

# %% [markdown]
# #### i also enjoy playing tennis
